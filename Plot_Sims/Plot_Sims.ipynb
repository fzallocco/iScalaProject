# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import math

import iscala_lib.main as main

# %%
df = main.set_df('data/l1', ['Topology', 'N'])
# main.check_data(df)
main.plot_data_from_folder(df, x_feature='N', y_feature='Number of Rounds',
                           label='Topology', log_x=False, log_y=True, rounds_vs_n=True)
# Out:
#             Topology  Expected N    L         I  Number of Graphs      N  \
# 4    Barabási–Albert         4.0  1.0  2.885390          100000.0    4.0
# 6    Barabási–Albert         8.0  1.0  3.431326          100000.0    8.0
# 1    Barabási–Albert        16.0  1.0  4.080558          100000.0   16.0
# 3    Barabási–Albert        32.0  1.0  4.852628          100000.0   32.0
# 5    Barabási–Albert        64.0  1.0  5.770780          100000.0   64.0
# 0    Barabási–Albert       128.0  1.0  6.862653          100000.0  128.0
# 2    Barabási–Albert       256.0  1.0  8.161116          100000.0  256.0
# 11       Erdős–Rényi         4.0  1.0  1.000000          100000.0    4.0
# 13       Erdős–Rényi         8.0  1.0  1.500000          100000.0    8.0
# 8        Erdős–Rényi        16.0  1.0  2.000000          100000.0   16.0
# 10       Erdős–Rényi        32.0  1.0  2.500000          100000.0   32.0
# 12       Erdős–Rényi        64.0  1.0  3.000000          100000.0   64.0
# 7        Erdős–Rényi       128.0  1.0  3.500000          100000.0  128.0
# 9        Erdős–Rényi       256.0  1.0  4.000000          100000.0  256.0
# 16              Path         4.0  1.0  0.500000          100000.0    4.0
# 17              Path         8.0  1.0  0.250000          100000.0    8.0
# 14              Path        16.0  1.0  0.125000          100000.0   16.0
# 15              Path        32.0  1.0  0.062500          100000.0   32.0
# 20  Random Geometric         4.0  1.0  1.681793          100000.0    4.0
# 22  Random Geometric         8.0  1.0  1.565085          100000.0    8.0
# 18  Random Geometric        16.0  1.0  1.414214          100000.0   16.0
# 19  Random Geometric        32.0  1.0  1.257433          100000.0   32.0
# 21  Random Geometric        64.0  1.0  1.106682          100000.0   64.0
# 26              Star         4.0  1.0  1.000000          100000.0    4.0
# 28              Star         8.0  1.0  1.000000          100000.0    8.0
# 24              Star        16.0  1.0  1.000000          100000.0   16.0
# 25              Star        32.0  1.0  1.000000          100000.0   32.0
# 27              Star        64.0  1.0  1.000000          100000.0   64.0
# 23              Star       128.0  1.0  1.000000          100000.0  128.0
# 32    Watts–Strogatz         4.0  1.0  0.336629          100000.0    4.0
# 34    Watts–Strogatz         8.0  1.0  0.448838          100000.0    8.0
# 30    Watts–Strogatz        16.0  1.0  0.673258          100000.0   16.0
# 31    Watts–Strogatz        32.0  1.0  1.077212          100000.0   32.0
# 33    Watts–Strogatz        64.0  1.0  1.795354          100000.0   64.0
# 29    Watts–Strogatz       128.0  1.0  3.077749          100000.0  128.0
#
#     Number of Rounds   Time Taken
# 4       1.249800e+04        102.0
# 6       1.220670e+05        481.0
# 1       1.067775e+06       1828.0
# 3       8.630195e+06      23241.0
# 5       6.612896e+07     316555.0
# 0       4.872625e+08    3691555.0
# 2       3.483037e+09   53590391.0
# 11      1.036520e+05        398.0
# 13      6.390000e+05        754.0
# 8       4.448656e+06       6711.0
# 10      3.254318e+07      87647.0
# 12      2.449014e+08    1268007.0
# 7       1.874955e+09   19864589.0
# 9       1.451175e+10  360923022.0
# 16      4.145990e+05       1093.0
# 17      2.300540e+07      23495.0
# 14      1.138954e+09    1680681.0
# 15      5.206931e+10  114384766.0
# 20      3.668000e+04        328.0
# 22      5.869670e+05       1231.0
# 18      8.897281e+06      26620.0
# 19      1.286328e+08    1428602.0
# 21      1.799616e+09   60323376.0
# 26      1.036520e+05        471.0
# 28      1.437653e+06       8150.0
# 24      1.779456e+07     104411.0
# 25      2.033859e+08    1147394.0
# 27      2.204070e+09    7509877.0
# 23      2.296795e+10  115630833.0
# 32      9.138340e+05       1753.0
# 34      7.129795e+06       8216.0
# 30      3.922342e+07     101712.0
# 31      1.751227e+08    1334125.0
# 33      6.831957e+08   13416490.0
# 29      2.422562e+09  175251673.0

# %%
df = main.set_df('data/n32', ['Topology', 'L'])
# main.check_data(df)
main.plot_data_from_folder(df, x_feature='L', y_feature='Number of Rounds',
                           label='Topology', log_x=False, log_y=True, rounds_vs_l=True)
# Out:
#             Topology  Expected N     L         I  Number of Graphs     N  \
# 1    Barabási–Albert        32.0   2.0  4.852628          100000.0  32.0
# 2    Barabási–Albert        32.0   4.0  4.852628          100000.0  32.0
# 3    Barabási–Albert        32.0   8.0  4.852628          100000.0  32.0
# 0    Barabási–Albert        32.0  16.0  4.852628          100000.0  32.0
# 5        Erdős–Rényi        32.0   2.0  2.500000          100000.0  32.0
# 6        Erdős–Rényi        32.0   4.0  2.500000          100000.0  32.0
# 7        Erdős–Rényi        32.0   8.0  2.500000          100000.0  32.0
# 4        Erdős–Rényi        32.0  16.0  2.500000          100000.0  32.0
# 9               Path        32.0   2.0  0.062500          100000.0  32.0
# 10              Path        32.0   4.0  0.062500          100000.0  32.0
# 11              Path        32.0   8.0  0.062500          100000.0  32.0
# 8               Path        32.0  16.0  0.062500          100000.0  32.0
# 13  Random Geometric        32.0   2.0  1.257433          100000.0  32.0
# 14  Random Geometric        32.0   4.0  1.257433          100000.0  32.0
# 15  Random Geometric        32.0   8.0  1.257433          100000.0  32.0
# 12  Random Geometric        32.0  16.0  1.257433          100000.0  32.0
# 17              Star        32.0   2.0  1.000000          100000.0  32.0
# 18              Star        32.0   4.0  1.000000          100000.0  32.0
# 19              Star        32.0   8.0  1.000000          100000.0  32.0
# 16              Star        32.0  16.0  1.000000          100000.0  32.0
# 21    Watts-Strogatz        32.0   2.0  1.077212          100000.0  32.0
# 22    Watts-Strogatz        32.0   4.0  1.077212          100000.0  32.0
# 23    Watts-Strogatz        32.0   8.0  1.077212          100000.0  32.0
# 20    Watts-Strogatz        32.0  16.0  1.077212          100000.0  32.0
#
#     Number of Rounds   Time Taken
# 1       3.314462e+07    1097889.0
# 2       9.802009e+06     395744.0
# 3       3.925019e+06     186493.0
# 0       1.235798e+06      67325.0
# 5       1.248722e+08    3787216.0
# 6       3.693076e+07    1262180.0
# 7       1.478874e+07     586903.0
# 4       4.655959e+06     249439.0
# 9       1.997959e+11  441151976.0
# 10      5.908976e+10  327172865.0
# 11      2.366186e+10  170089272.0
# 8       7.449441e+09   67813137.0
# 13      4.935865e+08    6872387.0
# 14      1.459730e+08    3809690.0
# 15      5.845068e+07    1976849.0
# 12      1.840413e+07     668475.0
# 17      7.804280e+08    3163652.0
# 18      2.308034e+08    1628277.0
# 19      9.241868e+07     800233.0
# 16      2.909945e+07     284261.0
# 21      6.725603e+08   25319725.0
# 22      1.989022e+08    9506242.0
# 23      7.964493e+07    3983123.0
# 20      2.507739e+07    1471781.0
